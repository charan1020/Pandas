# %%
import pandas as pd

# %%
df=pd.read_csv("adult.csv")

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df[['age','workclass','race']]
# Out:
#        age          workclass    race
# 0       39          State-gov   White
# 1       50   Self-emp-not-inc   White
# 2       38            Private   White
# 3       53            Private   Black
# 4       28            Private   Black
# ...    ...                ...     ...
# 32556   27            Private   White
# 32557   40            Private   White
# 32558   58            Private   White
# 32559   22            Private   White
# 32560   52       Self-emp-inc   White
#
# [32561 rows x 3 columns]

# %%
pd.DataFrame(df['age'])
# Out:
#        age
# 0       39
# 1       50
# 2       38
# 3       53
# 4       28
# ...    ...
# 32556   27
# 32557   40
# 32558   58
# 32559   22
# 32560   52
#
# [32561 rows x 1 columns]

# %%
df[df['sex']==' Female'].ndim
# Out:
# 2

# %%
df['sex'].unique()
# Out:
# array([' Male', ' Female'], dtype=object)

# %%
df['race'].unique()
# Out:
# array([' White', ' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo',
#        ' Other'], dtype=object)

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# country           0
# salary            0
# dtype: int64

# %%
df[['race','sex']][[]]
# Out:
#   Cell In[17], line 1
#     df[['race'] [[age]]
#                        ^
# SyntaxError: incomplete input

# %%
df[['race','sex']]
# Out:
#          race      sex
# 0       White     Male
# 1       White     Male
# 2       White     Male
# 3       Black     Male
# 4       Black   Female
# ...       ...      ...
# 32556   White   Female
# 32557   White     Male
# 32558   White   Female
# 32559   White     Male
# 32560   White   Female
#
# [32561 rows x 2 columns]

# %%
df[df['age']==17]
# Out:
#        age workclass  fnlwgt education  education-num  marital-status  \
# 106     17         ?  304873      10th              6   Never-married
# 209     17   Private   65368      11th              7   Never-married
# 262     17   Private  245918      11th              7   Never-married
# 271     17   Private  191260       9th              5   Never-married
# 335     17   Private  270942   5th-6th              3   Never-married
# ...    ...       ...     ...       ...            ...             ...
# 31772   17         ?  256173      10th              6   Never-married
# 31864   17   Private  214787      12th              8   Never-married
# 31959   17   Private   24090   HS-grad              9   Never-married
# 32282   17   Private  311907      11th              7   Never-married
# 32447   17   Private  117798      10th              6   Never-married
#
#              occupation     relationship    race      sex  capital-gain  \
# ...

# %%
df.age.max()
# Out:
# 90

# %%
df[df['age']==90]
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 222     90            Private   51744        HS-grad              9
# 1040    90            Private  137018        HS-grad              9
# 1935    90            Private  221832      Bachelors             13
# 2303    90            Private   52386   Some-college             10
# 2891    90            Private  171956   Some-college             10
# 4070    90            Private  313986           11th              7
# 4109    90                  ?  256514      Bachelors             13
# 5104    90            Private   52386   Some-college             10
# 5272    90            Private  141758            9th              5
# 5370    90          Local-gov  227796        Masters             14
# 5406    90            Private   51744        Masters             14
# 6232    90   Self-emp-not-inc  155981      Bachelors             13
# 6624    90            Private  313986           11th              7
# ...

# %%
df.age.sum()
# Out:
# 1256257

# %%
df['age'][0:50:2]
# Out:
# 0     39
# 2     38
# 4     28
# 6     49
# 8     31
# 10    37
# 12    23
# 14    40
# 16    25
# 18    38
# 20    40
# 22    35
# 24    59
# 26    19
# 28    39
# 30    23
# 32    45
# 34    22
# 36    21
# 38    31
# 40    31
# 42    24
# 44    25
# 46    53
# 48    41
# Name: age, dtype: int64

# %%
df[['age','sex']][:50]
# Out:
#     age      sex
# 0    39     Male
# 1    50     Male
# 2    38     Male
# 3    53     Male
# 4    28   Female
# 5    37   Female
# 6    49   Female
# 7    52     Male
# 8    31   Female
# 9    42     Male
# 10   37     Male
# 11   30     Male
# 12   23   Female
# 13   32     Male
# 14   40     Male
# 15   34     Male
# 16   25     Male
# 17   32     Male
# 18   38     Male
# 19   43   Female
# 20   40     Male
# 21   54   Female
# 22   35     Male
# 23   43     Male
# 24   59   Female
# 25   56     Male
# 26   19     Male
# 27   54     Male
# 28   39     Male
# 29   49     Male
# 30   23     Male
# 31   20     Male
# 32   45     Male
# 33   30     Male
# 34   22     Male
# 35   48     Male
# 36   21     Male
# 37   19   Female
# 38   31     Male
# 39   48     Male
# 40   31     Male
# 41   53     Male
# 42   24     Male
# 43   49   Female
# 44   25     Male
# 45   57     Male
# 46   53     Male
# 47   44   Female
# 48   41     Male
# 49   29     Male

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df['age1']=[78,89,90,67]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24240\2642393013.py in <module>
# ----> 1 df['age1']=[78,89,90,67]
#
# NameError: name 'df' is not defined

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df.drop(['age1'],axis=1)
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df.drop(['age1','sex'],axis=1)
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df.drop(df.columns[[0,5,6]],axis=1)
# Out:
#                workclass  fnlwgt    education  education-num    relationship  \
# 0              State-gov   77516    Bachelors             13   Not-in-family
# 1       Self-emp-not-inc   83311    Bachelors             13         Husband
# 2                Private  215646      HS-grad              9   Not-in-family
# 3                Private  234721         11th              7         Husband
# 4                Private  338409    Bachelors             13            Wife
# ...                  ...     ...          ...            ...             ...
# 32556            Private  257302   Assoc-acdm             12            Wife
# 32557            Private  154374      HS-grad              9         Husband
# 32558            Private  151910      HS-grad              9       Unmarried
# 32559            Private  201490      HS-grad              9       Own-child
# 32560       Self-emp-inc  287927      HS-grad              9            Wife
#
# ...

# %%
data={"Name":['raksha','setty'],'qualification':['b.e','mba']}

# %%
data
# Out:
# {'Name': ['raksha', 'setty'], 'qualification': ['b.e', 'mba']}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#      Name qualification
# 0  raksha           b.e
# 1   setty           mba

# %%
df['adress']=['delhi','ranchi']

# %%
df
# Out:
#      Name qualification  adress
# 0  raksha           b.e   delhi
# 1   setty           mba  ranchi

# %%
#how to import the library
#how to load the data
#head()
#tail
#describe
#info
#series
#dataframe
#how to retrieve the columns
#changing the columns name
#drop
#checking null values
#how to retrieve the data of specific datatype
#unique 
#slicing
#aggregates
#how to add new columns to the data set
#how to convert the data into dataframe
#how to convert the datatype into other datatype
#iloc()
#duplicates
#group by

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df.iloc[1:9,2:3]
# Out:
#    fnlwgt
# 1   83311
# 2  215646
# 3  234721
# 4  338409
# 5  284582
# 6  160187
# 7  209642
# 8   45781

# %%
df.iloc[0:5,0:]
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week         country  salary
# 0          2174             0              40   United-States   <=50K
# ...

# %%
df.duplicated().sum()
# Out:
# 24

# %%
df.drop_duplicates().shape
# Out:
# (32537, 15)

# %%
df[(df.age>20)&(df.sex==' Male')]
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 0       39          State-gov   77516      Bachelors             13
# 1       50   Self-emp-not-inc   83311      Bachelors             13
# 2       38            Private  215646        HS-grad              9
# 3       53            Private  234721           11th              7
# 7       52   Self-emp-not-inc  209642        HS-grad              9
# ...    ...                ...     ...            ...            ...
# 32553   32            Private  116138        Masters             14
# 32554   53            Private  321865        Masters             14
# 32555   22            Private  310152   Some-college             10
# 32557   40            Private  154374        HS-grad              9
# 32559   22            Private  201490        HS-grad              9
#
#             marital-status          occupation    relationship  \
# 0            Never-married        Adm-clerical   Not-in-family
# ...

# %%
df=pd.DataFrame({"name":["a","b","c","d","a","b","c","d","a","b","c","d"],"s_1":[2,3,4,5,67,78,90,45,76,78,9,45],"s_2":[4,5,98,67,76,78,67,56,56,78,90,67]})

# %%
df
# Out:
#    name  s_1  s_2
# 0     a    2    4
# 1     b    3    5
# 2     c    4   98
# 3     d    5   67
# 4     a   67   76
# 5     b   78   78
# 6     c   90   67
# 7     d   45   56
# 8     a   76   56
# 9     b   78   78
# 10    c    9   90
# 11    d   45   67

# %%
df.groupby("name")

# %%
for i,j in df:
    print(i)
    print(j)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 for i,j in df:
#       2     print(i)
#       3     print(j)
#
# ValueError: too many values to unpack (expected 2)

# %%
df1=df.groupby("name")
for i, j in df1:
    print(i)
    print(j)
    print(   )
# Out:
# a
#   name  s_1  s_2
# 0    a    2    4
# 4    a   67   76
# 8    a   76   56
#
# b
#   name  s_1  s_2
# 1    b    3    5
# 5    b   78   78
# 9    b   78   78
#
# c
#    name  s_1  s_2
# 2     c    4   98
# 6     c   90   67
# 10    c    9   90
#
# d
#    name  s_1  s_2
# 3     d    5   67
# 7     d   45   56
# 11    d   45   67

# %%
df.groupby(['workclass','race']).min()
# Out:
#                                        age  fnlwgt   education  education-num  \
# workclass         race
#  ?                 Amer-Indian-Eskimo   19   12285        10th              2
#                    Asian-Pac-Islander   17   20469        10th              2
#                    Black                17   32604        10th              1
#                    Other                17   33811        10th              3
#                    White                17   19793        10th              1
#  Federal-gov       Amer-Indian-Eskimo   23   19914        10th              6
#                    Asian-Pac-Islander   18   19914        11th              7
#                    Black                17   23494        11th              5
#                    Other                24   29591   Assoc-voc              9
#                    White                18   20179        10th              3
#  Local-gov         Amer-Indian-Eskimo   23   20101     1st-4th              2
# ...
