# %%
import pandas as pd

# %%
df=pd.read_csv("adult.csv")

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df[['age','workclass','age']]
# Out:
#        age          workclass  age
# 0       39          State-gov   39
# 1       50   Self-emp-not-inc   50
# 2       38            Private   38
# 3       53            Private   53
# 4       28            Private   28
# ...    ...                ...  ...
# 32556   27            Private   27
# 32557   40            Private   40
# 32558   58            Private   58
# 32559   22            Private   22
# 32560   52       Self-emp-inc   52
#
# [32561 rows x 3 columns]

# %%
pd.DataFrame(df['age'])
# Out:
#        age
# 0       39
# 1       50
# 2       38
# 3       53
# 4       28
# ...    ...
# 32556   27
# 32557   40
# 32558   58
# 32559   22
# 32560   52
#
# [32561 rows x 1 columns]

# %%
df[df['sex']==' Female'].ndim
# Out:
# 2

# %%
df['sex'].unique()
# Out:
# array([' Male', ' Female'], dtype=object)

# %%
df['race'].unique()
# Out:
# array([' White', ' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo',
#        ' Other'], dtype=object)

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# country           0
# salary            0
# dtype: int64

# %%
df[['race','sex']]
# Out:
#          race      sex
# 0       White     Male
# 1       White     Male
# 2       White     Male
# 3       Black     Male
# 4       Black   Female
# ...       ...      ...
# 32556   White   Female
# 32557   White     Male
# 32558   White   Female
# 32559   White     Male
# 32560   White   Female
#
# [32561 rows x 2 columns]

# %%
df[df['age']==17]
# Out:
#        age workclass  fnlwgt education  education-num  marital-status  \
# 106     17         ?  304873      10th              6   Never-married
# 209     17   Private   65368      11th              7   Never-married
# 262     17   Private  245918      11th              7   Never-married
# 271     17   Private  191260       9th              5   Never-married
# 335     17   Private  270942   5th-6th              3   Never-married
# ...    ...       ...     ...       ...            ...             ...
# 31772   17         ?  256173      10th              6   Never-married
# 31864   17   Private  214787      12th              8   Never-married
# 31959   17   Private   24090   HS-grad              9   Never-married
# 32282   17   Private  311907      11th              7   Never-married
# 32447   17   Private  117798      10th              6   Never-married
#
#              occupation     relationship    race      sex  capital-gain  \
# ...

# %%
df.age.max()
# Out:
# 90

# %%
df[df['age']==90]
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 222     90            Private   51744        HS-grad              9
# 1040    90            Private  137018        HS-grad              9
# 1935    90            Private  221832      Bachelors             13
# 2303    90            Private   52386   Some-college             10
# 2891    90            Private  171956   Some-college             10
# 4070    90            Private  313986           11th              7
# 4109    90                  ?  256514      Bachelors             13
# 5104    90            Private   52386   Some-college             10
# 5272    90            Private  141758            9th              5
# 5370    90          Local-gov  227796        Masters             14
# 5406    90            Private   51744        Masters             14
# 6232    90   Self-emp-not-inc  155981      Bachelors             13
# 6624    90            Private  313986           11th              7
# ...

# %%
df.age.sum()
# Out:
# 1256257

# %%
df['age'][0:50:2]
# Out:
# 0     39
# 2     38
# 4     28
# 6     49
# 8     31
# 10    37
# 12    23
# 14    40
# 16    25
# 18    38
# 20    40
# 22    35
# 24    59
# 26    19
# 28    39
# 30    23
# 32    45
# 34    22
# 36    21
# 38    31
# 40    31
# 42    24
# 44    25
# 46    53
# 48    41
# Name: age, dtype: int64

# %%
df[['age','sex']][:50]
# Out:
#     age      sex
# 0    39     Male
# 1    50     Male
# 2    38     Male
# 3    53     Male
# 4    28   Female
# 5    37   Female
# 6    49   Female
# 7    52     Male
# 8    31   Female
# 9    42     Male
# 10   37     Male
# 11   30     Male
# 12   23   Female
# 13   32     Male
# 14   40     Male
# 15   34     Male
# 16   25     Male
# 17   32     Male
# 18   38     Male
# 19   43   Female
# 20   40     Male
# 21   54   Female
# 22   35     Male
# 23   43     Male
# 24   59   Female
# 25   56     Male
# 26   19     Male
# 27   54     Male
# 28   39     Male
# 29   49     Male
# 30   23     Male
# 31   20     Male
# 32   45     Male
# 33   30     Male
# 34   22     Male
# 35   48     Male
# 36   21     Male
# 37   19   Female
# 38   31     Male
# 39   48     Male
# 40   31     Male
# 41   53     Male
# 42   24     Male
# 43   49   Female
# 44   25     Male
# 45   57     Male
# 46   53     Male
# 47   44   Female
# 48   41     Male
# 49   29     Male

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df.drop(['age'],axis=1)
# Out:
#                workclass  fnlwgt    education  education-num  \
# 0              State-gov   77516    Bachelors             13
# 1       Self-emp-not-inc   83311    Bachelors             13
# 2                Private  215646      HS-grad              9
# 3                Private  234721         11th              7
# 4                Private  338409    Bachelors             13
# ...                  ...     ...          ...            ...
# 32556            Private  257302   Assoc-acdm             12
# 32557            Private  154374      HS-grad              9
# 32558            Private  151910      HS-grad              9
# 32559            Private  201490      HS-grad              9
# 32560       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df.drop(['age','sex'],axis=1)
# Out:
#                workclass  fnlwgt    education  education-num  \
# 0              State-gov   77516    Bachelors             13
# 1       Self-emp-not-inc   83311    Bachelors             13
# 2                Private  215646      HS-grad              9
# 3                Private  234721         11th              7
# 4                Private  338409    Bachelors             13
# ...                  ...     ...          ...            ...
# 32556            Private  257302   Assoc-acdm             12
# 32557            Private  154374      HS-grad              9
# 32558            Private  151910      HS-grad              9
# 32559            Private  201490      HS-grad              9
# 32560       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
df.drop(df.columns[[0,5,6]],axis=1)
# Out:
#                workclass  fnlwgt    education  education-num    relationship  \
# 0              State-gov   77516    Bachelors             13   Not-in-family
# 1       Self-emp-not-inc   83311    Bachelors             13         Husband
# 2                Private  215646      HS-grad              9   Not-in-family
# 3                Private  234721         11th              7         Husband
# 4                Private  338409    Bachelors             13            Wife
# ...                  ...     ...          ...            ...             ...
# 32556            Private  257302   Assoc-acdm             12            Wife
# 32557            Private  154374      HS-grad              9         Husband
# 32558            Private  151910      HS-grad              9       Unmarried
# 32559            Private  201490      HS-grad              9       Own-child
# 32560       Self-emp-inc  287927      HS-grad              9            Wife
#
# ...

# %%
data={"Name":['raksha','setty'],'qualification':['b.e','mba']}

# %%
data
# Out:
# {'Name': ['raksha', 'setty'], 'qualification': ['b.e', 'mba']}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#      Name qualification
# 0  raksha           b.e
# 1   setty           mba

# %%
df['adress']=['delhi','ranchi']
